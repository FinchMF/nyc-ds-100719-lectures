# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
# %matplotlib inline

# %%
#Load our dataframe account for the index columns
df = pd.read_csv('case_study.csv', index_col= 0)
# Out:
# /Users/Finch/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3057: DtypeWarning: Columns (171) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head()
# Out:
#        _STATE  FMONTH    IDATE  IMONTH  IDAY  IYEAR  DISPCODE       SEQNO  \
# 49938     9.0     5.0  5172017       5    17   2017    1200.0  2017000001
# 49939     9.0     2.0  2142017       2    14   2017    1200.0  2017000002
# 49940     9.0     1.0  1292017       1    29   2017    1200.0  2017000003
# 49941     9.0     7.0  9112017       9    11   2017    1200.0  2017000004
# 49942     9.0     5.0  7182017       7    18   2017    1200.0  2017000005
#
#                _PSU  CTELENM1  ...  _PA300R2  _PA30021  _PASTRNG  _PAREC1  \
# 49938  2.017000e+09       NaN  ...       2.0       2.0       2.0      4.0
# 49939  2.017000e+09       NaN  ...       1.0       1.0       1.0      1.0
# 49940  2.017000e+09       NaN  ...       3.0       2.0       1.0      3.0
# 49941  2.017000e+09       NaN  ...       2.0       2.0       2.0      2.0
# 49942  2.017000e+09       NaN  ...       2.0       2.0       1.0      1.0
#
#        _PASTAE1  _RFSEAT2  _RFSEAT3  _FLSHOT6  _PNEUMO2  _AIDTST3
# ...

# %%
# Quickly check to see the size of our DF, both rows and columns
df.shape
# Out:
# (34545, 358)

# %% [markdown]
# ## Subset your dataframe to only include the states in the tri-state area (NJ, CT, NY)

# %%
df['_STATE']
# Out:
# 49938      9.0
# 49939      9.0
# 49940      9.0
# 49941      9.0
# 49942      9.0
# 49943      9.0
# 49944      9.0
# 49945      9.0
# 49946      9.0
# 49947      9.0
# 49948      9.0
# 49949      9.0
# 49950      9.0
# 49951      9.0
# 49952      9.0
# 49953      9.0
# 49954      9.0
# 49955      9.0
# 49956      9.0
# 49957      9.0
# 49958      9.0
# 49959      9.0
# 49960      9.0
# 49961      9.0
# 49962      9.0
# 49963      9.0
# 49964      9.0
# 49965      9.0
# 49966      9.0
# 49967      9.0
#           ...
# 303749    36.0
# 303750    36.0
# 303751    36.0
# 303752    36.0
# 303753    36.0
# 303754    36.0
# 303755    36.0
# 303756    36.0
# 303757    36.0
# 303758    36.0
# 303759    36.0
# 303760    36.0
# 303761    36.0
# 303762    36.0
# 303763    36.0
# 303764    36.0
# 303765    36.0
# 303766    36.0
# 303767    36.0
# 303768    36.0
# 303769    36.0
# 303770    36.0
# 303771    36.0
# 303772    36.0
# 303773    36.0
# 303774    36.0
# 303775    36.0
# ...

# %%
tristates = [9,34,36]

# %%
df[df['_STATE'].isin(tristates)]
# Out:
#         _STATE  FMONTH     IDATE  IMONTH  IDAY  IYEAR  DISPCODE       SEQNO  \
# 49938      9.0     5.0   5172017       5    17   2017    1200.0  2017000001
# 49939      9.0     2.0   2142017       2    14   2017    1200.0  2017000002
# 49940      9.0     1.0   1292017       1    29   2017    1200.0  2017000003
# 49941      9.0     7.0   9112017       9    11   2017    1200.0  2017000004
# 49942      9.0     5.0   7182017       7    18   2017    1200.0  2017000005
# 49943      9.0     1.0   1192017       1    19   2017    1100.0  2017000006
# 49944      9.0     1.0   2032017       2     3   2017    1100.0  2017000007
# 49945      9.0     1.0   2012017       2     1   2017    1100.0  2017000008
# 49946      9.0     1.0   1262017       1    26   2017    1100.0  2017000009
# 49947      9.0     1.0   1192017       1    19   2017    1100.0  2017000010
# 49948      9.0     1.0   1242017       1    24   2017    1100.0  2017000011
# ...

# %% [markdown]
# Now check to see how large our subset df.

# %%
# your code here

# %% [markdown]
# **PHYSHLTH** is the column we are interested in for this analysis, so let's start to investigate the column. Since we have a data cookbook, a.k.a. data dictionary) we want to start there before looking at the code.

# %%
df['PHYSHLTH'].describe()
# Out:
# count    34545.000000
# mean        60.213403
# std         37.504566
# min          1.000000
# 25%         15.000000
# 50%         88.000000
# 75%         88.000000
# max         99.000000
# Name: PHYSHLTH, dtype: float64

# %%
df['PHYSHLTH'].describe()
# Out:
# count    34545.000000
# mean        60.213403
# std         37.504566
# min          1.000000
# 25%         15.000000
# 50%         88.000000
# 75%         88.000000
# max         99.000000
# Name: PHYSHLTH, dtype: float64

# %% [markdown]
# ## 1. Handle the non-normal values
#
# As you can see from the data dictionary, there are a number of responses that are coded with values that could throw off our descriptive statistics.  Let's clean up by mapping the responses to a more appropriate value, and handling any missing values.

# %%
#your code here
zero_dict = {88:0,
             77:np.nan,
             99:np.nan}
df['PHYSHLTH'] = df['PHYSHLTH'].replace(zero_dict)

df['PHYSHLTH'].describe()
# Out:
# count    33747.000000
# mean         4.085341
# std          8.513293
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          3.000000
# max         30.000000
# Name: PHYSHLTH, dtype: float64

# %% [markdown]
# ## 2. Generate the descriptive statistics
#
# Now that our target variable is cleaned up lets calculate the descriptive statistics, generate a graph that quickly shows those statistics, and generate a gprah shows the histogram of the data.

# %%
target = df['PHYSHLTH'].describe()
target
# Out:
# count    33747.000000
# mean         4.085341
# std          8.513293
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          3.000000
# max         30.000000
# Name: PHYSHLTH, dtype: float64

# %%
df_target = pd.DataFrame(df['PHYSHLTH'])

# %%
# graphic showing those descriptive stats
sns.set_style("whitegrid")
sns.boxplot(df_target)

# %%
# graphic showing the distribution of data
sns.set_style("whitegrid")
sns.distplot(df['PHYSHLTH'].dropna(), kde=False)

# %% [markdown]
# ## 3. Generate a graphic that compares the average number of sick days for each state.

# %%
# code to calculate the average number of sick days by state
mean_state = pd.DataFrame(df.groupby("_STATE")['PHYSHLTH'].mean()).reset_index()
mean_state
# Out:
#    _STATE  PHYSHLTH
# 0     9.0  3.688562
# 1    34.0  4.380957
# 2    36.0  4.148030

# %%
# code to graph those averages using matplotlib
mean_state
sns.barplot(x=mean_state['_STATE'], y=mean_state["PHYSHLTH"], data=mean_state)

# %% [markdown]
# ## 4. Turn the number of sick days into a classification of of chronically sick people.
#
# Chronically sick people account for a significant proportion of the costs for health insurers. If we can identify what leads people to be chronically sick, we can address them with specific treatments.

# %%
# code to create new colum for chronically sick
upper_limit = df['PHYSHLTH'].dropna().mean() + (2 * df['PHYSHLTH'].dropna().std())
upper_limit


# df['CHRONIC'] = df['PHYSHLTH'].map(lambda x: 1 if x > upper_limit else 0) 
# df[df['CHRONIC'] == 1].shape
# Out:
# 21.111926224003277

# %%
df['CHRONIC'] = df['PHYSHLTH'].map(lambda x: 1 if x > upper_limit else 0) 
df[df['CHRONIC'] == 1].shape
# Out:
# (2741, 359)

# %%
df["CHRONIC"]
# Out:
# 49938     0
# 49939     0
# 49940     0
# 49941     0
# 49942     0
# 49943     0
# 49944     0
# 49945     0
# 49946     1
# 49947     0
# 49948     0
# 49949     0
# 49950     0
# 49951     0
# 49952     0
# 49953     0
# 49954     0
# 49955     1
# 49956     0
# 49957     0
# 49958     0
# 49959     0
# 49960     0
# 49961     0
# 49962     0
# 49963     0
# 49964     0
# 49965     0
# 49966     0
# 49967     0
#          ..
# 303749    0
# 303750    0
# 303751    1
# 303752    0
# 303753    0
# 303754    0
# 303755    0
# 303756    0
# 303757    0
# 303758    0
# 303759    0
# 303760    0
# 303761    0
# 303762    0
# 303763    0
# 303764    0
# 303765    0
# 303766    0
# 303767    0
# 303768    0
# 303769    0
# 303770    0
# 303771    0
# 303772    0
# 303773    0
# 303774    0
# 303775    0
# 303776    0
# 303777    0
# 303778    0
# Name: CHRONIC, Length: 34545, dtype: int64

# %% [markdown]
# ## 5. Create a graphic that compares the percentage of people labeled as 'sick' in each state.

# %%
# code to calculate averages per state
by_state = df.groupby('_STATE')["CHRONIC"].mean()
by_state
# Out:
# _STATE
# 9.0     0.070174
# 34.0    0.090195
# 36.0    0.076904
# Name: CHRONIC, dtype: float64

# %%
# create graphic to compare chronically sick by state

by_state.plot.bar()

# %% [markdown]
# ## 6. Independent Variables (categorical)
#
# Let's take the column `SMOKDAY2` and start to prepare it so that we can see how it is possibly correlated to `PHYSHLTH`.
#
# 1. Clean up the values.
# 2. Calculate the descriptive statistics of the variable.
# 3. Generate a histogram for the variable.
# 4. Generate graphics that show how the responses to this variable might differ by state.
# 5. Generate a graphic that compares the physical health of the different groups of 'smokers'.

# %%
# 0 = not smoking
# 1 = some days
# 2 = every day

# smoke_codes = {3:0, 
#                2:1, 
#                1:2, 
#                7:np.nan, 
#                9:np.nan,
#               np.nan:np.nan}
# df['SMOKDAY2'] = df['SMOKDAY2'].replace(smoke_codes)
# df['SMOKDAY2'].value_counts()

# df[pd.isna(df['SMOKDAY2']) & (df["SMOKE100"] == 1)] 

# df[pd.isna(df['SMOKDAY2']) & df['SMOKE100'] == 2]

# df[pd.isna(df['SMOKDAY2'])].shape
# df[pd.isna(df['SMOKE100'])].shape
# Out:
# (1438, 359)

# %%
df['SMOKDAY2'].describe()
# Out:
# count    13783.000000
# mean         2.525720
# std          0.853626
# min          1.000000
# 25%          2.000000
# 50%          3.000000
# 75%          3.000000
# max          9.000000
# Name: SMOKDAY2, dtype: float64

# %%
sns.distplot(df['SMOKDAY2'].dropna())

# %% [markdown]
# ## 7. Independent Variables (continuous):
#
# Now let's look at a continuous variable (ALCDAY5) and see how that might impact a person's health.
#
# 1. Clean up the values.
# 2. Calculate the descriptive statistics of the variable.
# 3. Generate a histogram for the variable.
# 4. Generate graphics that show how the responses to this variable might differ by state.
# 5. Calculate the correlation coefficient between `PHYSHLTH` and `ALCDAY5`.
# 5. Generate a graphic that shows the possible relationship between `PHYSHLTH` and `ALCDAY5`.

# %%
df.loc[(df['ALCDAY5']>200) & (df['ALCDAY5']<231)]
# Out:
#         _STATE  FMONTH     IDATE  IMONTH  IDAY  IYEAR  DISPCODE       SEQNO  \
# 49939      9.0     2.0   2142017       2    14   2017    1200.0  2017000002
# 49944      9.0     1.0   2032017       2     3   2017    1100.0  2017000007
# 49945      9.0     1.0   2012017       2     1   2017    1100.0  2017000008
# 49947      9.0     1.0   1192017       1    19   2017    1100.0  2017000010
# 49949      9.0     1.0   1192017       1    19   2017    1100.0  2017000012
# 49952      9.0     1.0   1262017       1    26   2017    1100.0  2017000015
# 49953      9.0     1.0   1202017       1    20   2017    1100.0  2017000016
# 49954      9.0     1.0   1212017       1    21   2017    1100.0  2017000017
# 49955      9.0     1.0   1312017       1    31   2017    1100.0  2017000018
# 49957      9.0     1.0   1252017       1    25   2017    1100.0  2017000020
# 49959      9.0     1.0   1232017       1    23   2017    1100.0  2017000022
# ...

# %%
def convert_day(x):
    if 200<x<231:
        return x-200
    elif 101 <=x<= 107:
        return  x-100
    elif x == 888:
        return  0
    else:
        return np.nan
    
df['ALCDAY5'] = df['ALCDAY5'].map(lambda x: convert_day(x))

# %%
df['ALCDAY5'].value_counts()
# Out:
# 0.0     13043
# 1.0      4623
# 2.0      3556
# 3.0      2132
# 4.0      1530
# 5.0      1508
# 30.0     1164
# 7.0       988
# 10.0      840
# 20.0      650
# 15.0      590
# 6.0       498
# 8.0       369
# 25.0      265
# 12.0      144
# 28.0       56
# 14.0       53
# 29.0       31
# 9.0        28
# 27.0       24
# 18.0       19
# 16.0       15
# 26.0       15
# 24.0       14
# 22.0       13
# 21.0       13
# 13.0       11
# 11.0       10
# 17.0        7
# 23.0        2
# 19.0        1
# Name: ALCDAY5, dtype: int64

# %%
def drink_clean(x):
    if 1<=x<=76:
        return x
    else:
        return 0
df['AVEDRNK2'] = df['AVEDRNK2'].map(lambda x: drink_clean(x))

# %%
df['Drink_month'] = df['AVEDRNK2']*df['ALCDAY5']

# %%
df['Drink_month'].describe()
# Out:
# count    32212.000000
# mean         8.467621
# std         27.950828
# min          0.000000
# 25%          0.000000
# 50%          1.000000
# 75%          7.000000
# max       2280.000000
# Name: Drink_month, dtype: float64

# %%
sns.boxplot(df['Drink_month'].dropna())

# %%
df.loc[df['Drink_month'].idxmax(), 'Drink_month'] = np.nan

# %%
sns.boxplot(df['Drink_month'].dropna())

# %%
sns.distplot(df['Drink_month'].dropna())

# %%
df.groupby('_STATE')['Drink_month'].mean()
# Out:
# _STATE
# 9.0     8.775599
# 34.0    7.987060
# 36.0    8.466939
# Name: Drink_month, dtype: float64

# %%
sns.scatterplot(df['ALCDAY5'], df['PHYSHLTH'], alpha =.1)

# %%
df['ALCDAY5'].corr(df['PHYSHLTH'])
# Out:
# -0.0712091235434931

# %% [markdown]
# ## 8. Additional variables: Choose two additional survey items you would like to investigate do steps  6 or 7 for those variables.

# %%
# your code here

# %% [markdown]
# ## 9. Based on your initial data exploration, what are some hypotheses of what affects a person's health that you would like to further investigate?

# %% [markdown]
# Type out your initial hyptotheses below:
#
# 1.
#
# 2.
#
# 3.

# %% [markdown]
# ## Bonus: Create some cool graphics.
